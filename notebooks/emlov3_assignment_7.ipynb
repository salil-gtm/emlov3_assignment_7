# %% [markdown]
# # Check Python Version

# %%
! python --version
# Out:
# Python 3.10.12

# %%
# ! sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.8 1

# %%
# ! sudo update-alternatives --config python3

# %%
# !python3 --version

# %%
# ! sudo apt-get install pip

# %% [markdown]
# # Git Clone - Assignment Repo

# %%
! git clone https://github.com/salil-gtm/emlov3_assignment_7.git
# Out:
# Cloning into 'emlov3_assignment_7'...
# remote: Enumerating objects: 158, done.
# remote: Counting objects: 100% (158/158), done.
# remote: Compressing objects: 100% (120/120), done.
# remote: Total 158 (delta 65), reused 117 (delta 31), pack-reused 0
# Receiving objects: 100% (158/158), 203.37 KiB | 9.24 MiB/s, done.
# Resolving deltas: 100% (65/65), done.

# %%
# %cd emlov3_assignment_7
# Out:
# /content/emlov3_assignment_7

# %%
# !pip install --quiet -r requirements.txt
# !pip install --quiet -e .
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 36.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 729.2/729.2 kB 53.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 80.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 4.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 78.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 427.4/427.4 kB 33.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 13.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.1/18.1 MB 66.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 35.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.8/202.8 kB 24.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 71.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 9.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Test Tuner

# %% [markdown]
# - Keep "override /hparams_search:" as null when only testing tuner.

# %%
! adamantium_train experiment=hp_gpt data.num_workers=8
# Out:
# [2023-07-15 04:15:44,285][adamantium.utils.utils][WARNING] - Extras config not found! <cfg.extras=null>
# [2023-07-15 04:15:44,285][adamantium.train][INFO] - Instantiating datamodule <adamantium.data.hp_datamodule.HarryPotterDataModule>
# [2023-07-15 04:15:44,294][adamantium.train][INFO] - Instantiating model <adamantium.models.gpt_module.GPTLitModule>
# [2023-07-15 04:15:44,525][adamantium.train][INFO] - Instantiating callbacks...
# [2023-07-15 04:15:44,526][adamantium.utils.instantiators][INFO] - Instantiating callback <lightning.pytorch.callbacks.ModelCheckpoint>
# [2023-07-15 04:15:44,538][adamantium.utils.instantiators][INFO] - Instantiating callback <lightning.pytorch.callbacks.EarlyStopping>
# [2023-07-15 04:15:44,539][adamantium.utils.instantiators][INFO] - Instantiating callback <lightning.pytorch.callbacks.RichModelSummary>
# [2023-07-15 04:15:44,540][adamantium.utils.instantiators][INFO] - Instantiating callback <lightning.pytorch.callbacks.RichProgressBar>
# ...

# %% [markdown]
# # Running Optuna - Hyperparameter Optimization

# %% [markdown]
# - Switching back to "override /hparams_search: hp_optuna.yaml"

# %%
# ! adamantium_train -m experiment=hp_gpt data.num_workers=2 tuner=False

# %% [markdown]
# Ran the above experiment over terminal as running it in Jupyter Notebook made the browser really slow because of heavy logging.
